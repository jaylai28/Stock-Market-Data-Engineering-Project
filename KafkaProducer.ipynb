# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['yourlocalhost:9092'],
                         value_serializer=lambda x:
                         dumps(x).encode('utf-8'))

# %%
df = pd.read_csv("data/data.csv")
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
while True:
    dict_stock = df.sample(1).to_dict(orient='records')[0]
    print(producer.send('demo_test', value=dict_stock))
    sleep(1)
# Out:
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb087c70>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39f490>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f310>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f0d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f250>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79490>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fb20>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397f9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46eca0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46e280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb22a250>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f580>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fbe50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f1f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac799a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f970>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79a30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fa00>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac795e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fbeb0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fbe50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cad8cb20>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39f400>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb087fd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46ea00>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46e3a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397f280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fdf0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f790>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f5e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f3d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79d30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f250>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79f10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0ff40>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f7c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79490>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79040>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79340>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79460>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac795e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79310>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f250>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fa00>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f7f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f0a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f790>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f370>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fd60>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fe50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6ff10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fc10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f190>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f580>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fa30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f4c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac798b0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fdf0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79730>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f2e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f730>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79fa0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac798e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f370>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397ff10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f6d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46e3a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b396bdf0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39f370>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cab415e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cad8cf40>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac790d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fb9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79460>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79cd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f0d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79dc0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fe50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79f10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb22a1f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cab415e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f580>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397f5b0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397fc70>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39fbb0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f400>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46e910>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f310>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fb4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f1c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f100>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f970>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79cd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f6d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79220>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fa00>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fd30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79d30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac793d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79a90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79f10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79e50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79040>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fca0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f700>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fbb0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fb50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f2e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f7c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fee0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f1c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f580>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6faf0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f400>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fca0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f070>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fa60>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79670>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fba90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79100>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46ee80>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79d60>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f220>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6ffd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79340>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f700>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39f400>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f370>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397f9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b396b220>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6c91d18b0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb475370>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb22a1f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f100>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79bb0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fa90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79dc0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f3d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac798e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac799a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cab415e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cad8cb20>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46ea00>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46ef10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fb9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fba90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39fbb0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397ff10>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fd90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f850>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79cd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f3d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac799a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f490>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f970>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79e50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79c70>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79d30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79fd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79310>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79d00>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f310>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f9a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fd60>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6faf0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fbb0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f7f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f2e0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f250>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f5b0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f3d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f100>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f1c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fee0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fd30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79ac0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6fcd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79880>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f2b0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac6f220>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79fd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79460>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f0d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397f280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39f490>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac797c0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fba90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fb4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46ee80>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cad8cfd0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cde86dc0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f580>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79a30>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f6a0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79e80>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79700>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac79e50>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f6d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6c91cd880>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cad8cb20>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fb4f0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb1fba90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac7f160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb39f520>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f160>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cb46e280>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0fd90>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6b397f790>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f6d0>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f790>
# <kafka.producer.future.FutureRecordMetadata object at 0x7fd6cac0f4f0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 4
#       2 dict_stock = df.sample(1).to_dict(orient='records')[0]
#       3 print(producer.send('demo_test', value=dict_stock))
# ----> 4 sleep(1)
#
# KeyboardInterrupt:
